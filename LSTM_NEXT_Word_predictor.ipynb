# %%
story_text = '''
Aryan was no ordinary boy. While most kids in his village spent their time playing games, Aryan preferred to ask questions — about stars, trees, and everything in between.

He lived in a small cottage at the edge of the village, just where the forest began. His grandmother often told him stories of magical lands hidden deep within those woods.

One morning, as the sun peeked through the misty trees, Aryan packed a bag with bread, a bottle of water, and his old compass. Today, he was going to explore beyond the known trails.

The forest greeted him with birdsong and golden light filtering through the branches. Each step he took felt like an invitation to something greater.

He walked past the familiar oak tree, the one shaped like a question mark, and turned into a narrow path he had never noticed before.

Leaves rustled under his feet, and a cool breeze brushed his face. It smelled of pine, earth, and mystery.

As he walked deeper, the forest grew quieter. The usual chirping of birds faded, replaced by a distant humming sound, almost like music.

He followed the sound, curious and excited. The path opened into a small clearing, where a waterfall spilled into a crystal-clear pond.

Near the pond sat an old man with a long white beard, humming softly to himself and carving something into a piece of wood.

Aryan stepped forward hesitantly. The old man looked up and smiled. “You’ve found the first gate,” he said, as if expecting him.

Confused but intrigued, Aryan asked, “What gate? What is this place?”

The man chuckled. “This is the edge of the Hidden Valley. Only those who truly seek can find it. But each gate asks for a gift.”

Aryan thought for a moment and reached into his bag. He pulled out his compass and offered it. “This has guided me here.”

The man accepted the compass with both hands and placed it inside a wooden box. The trees around them suddenly shimmered.

A path revealed itself beyond the clearing, glowing faintly. “Follow it,” the old man said, “but remember — not everything is what it seems.”

Aryan stepped onto the glowing trail. The air felt thicker, filled with energy. He could hear faint whispers as if the forest were alive.

The path led to a stone archway, half-buried in vines. Strange symbols were carved into its surface, pulsing with soft blue light.

As he approached the arch, the symbols rearranged themselves, forming a riddle: “I speak without a mouth and hear without ears. What am I?”

Aryan paused, thinking hard. Then he whispered, “An echo.” The symbols flared brightly, and the arch opened into a spiraling tunnel of light.

With a deep breath, Aryan stepped into the tunnel. Colors swirled around him, and the ground beneath him vanished. His journey had truly begun.

The tunnel felt endless, yet Aryan wasn't afraid. Strange voices echoed around him — not loud, not scary, but soft and curious.

Suddenly, the light faded, and Aryan found himself standing in a vast hall filled with mirrors. Each mirror reflected a different version of him.

One showed him older and stronger, another smaller and afraid. A third mirror showed him surrounded by stars, holding a book with a glowing symbol.

He reached out to touch the starry mirror, and it rippled like water. Without thinking, Aryan stepped through.

On the other side, he stood on a platform floating in the sky. Strange flying creatures soared above, and silver bridges connected floating islands.

A small mechanical bird flew to him and landed on his shoulder. “Keyholder Aryan, your presence is logged,” it chirped.

“Keyholder?” Aryan whispered. He had never heard that term before.

The bird’s eyes glowed blue. “Only the brave who pass the first gate can unlock the truth of the valley.”

The bird flapped its wings and pointed toward a silver bridge. “Follow the path. The guardian awaits your question.”

Aryan crossed the bridge, each step echoing in the sky. Beneath him, clouds swirled like living creatures.

At the end of the bridge stood a tall figure wrapped in a cloak made of feathers and stars.

“You seek the Valley’s secret,” the figure said without moving. “But first, answer me this: Why do you walk alone?”

Aryan took a deep breath. “Because no one else believed. I had to believe for myself.”

The guardian nodded slowly. “Then the second gate shall open.” A golden feather floated from his cloak.

As Aryan caught the feather, the platform cracked, and everything around him began to dissolve into light.

He felt no fear. Instead, he felt lighter — like he was becoming part of something larger.

The light faded again, and Aryan landed gently in a circular garden glowing with blue and gold flowers.

In the center of the garden stood a tree made of crystal. Hanging from its branches were dozens of keys, each glowing in a different color.

A voice echoed from the sky: “Choose wisely. Only one key opens the door you truly seek.”

Aryan looked at the keys carefully. Then, guided by instinct, he reached for the smallest one — dull silver with a faint hum.
'''

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts([story_text])

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('aryan', 19),
#              ('was', 3),
#              ('no', 3),
#              ('ordinary', 1),
#              ('boy', 1),
#              ('while', 1),
#              ('most', 1),
#              ('kids', 1),
#              ('in', 11),
#              ('his', 10),
#              ('village', 2),
#              ('spent', 1),
#              ('their', 1),
#              ('time', 1),
#              ('playing', 1),
#              ('games', 1),
#              ('preferred', 1),
#              ('to', 9),
#              ('ask', 1),
#              ('questions', 1),
#              ('—', 5),
#              ('about', 1),
#              ('stars', 3),
#              ('trees', 3),
#              ('and', 27),
#              ('everything', 3),
#              ('between', 1),
#              ('he', 19),
#              ('lived', 1),
#              ('a', 38),
#              ('small', 3),
#              ('cottage', 1),
#              ('at', 3),
#              ('the', 65),
# ...

# %%
for sentence in story_text.split('/n'):
    print(sentence)
# Out:
# Aryan was no ordinary boy. While most kids in his village spent their time playing games, Aryan preferred to ask questions — about stars, trees, and everything in between.
#
# He lived in a small cottage at the edge of the village, just where the forest began. His grandmother often told him stories of magical lands hidden deep within those woods.
#
# One morning, as the sun peeked through the misty trees, Aryan packed a bag with bread, a bottle of water, and his old compass. Today, he was going to explore beyond the known trails.
#
# The forest greeted him with birdsong and golden light filtering through the branches. Each step he took felt like an invitation to something greater.
#
# He walked past the familiar oak tree, the one shaped like a question mark, and turned into a narrow path he had never noticed before.
#
# Leaves rustled under his feet, and a cool breeze brushed his face. It smelled of pine, earth, and mystery.
#
# ...

# %%
input_sequences = []
target_words = []

for sentence in story_text.split('\n'):
    sentence = sentence.strip()
    if sentence:
        tokens = tokenizer.texts_to_sequences([sentence])[0]
        for i in range(1, len(tokens)):
            input_seq = tokens[:i]
            target_seq = tokens[i]
            input_sequences.append(input_seq)
            target_words.append(target_seq)

# %%
max_len_input = max([len(seq) for seq in input_sequences])

# %%
print("Max input length:", max_len_input)
# Out:
# Max input length: 33

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X=pad_sequences(input_sequences, maxlen=max_len_input, padding='pre')

# %%
X
# Out:
# array([[  0,   0,   0, ...,   0,   0,   4],
#        [  0,   0,   0, ...,   0,   4,  34],
#        [  0,   0,   0, ...,   4,  34,  35],
#        ...,
#        [  0,   0,   0, ..., 412,  65,  10],
#        [  0,   0,   0, ...,  65,  10,   2],
#        [  0,   0,   0, ...,  10,   2, 112]], dtype=int32)

# %%
from tensorflow.keras.utils import to_categorical
total_words = len(tokenizer.word_index) + 1
y = to_categorical(target_words, num_classes=total_words)

# %%
X.shape,y.shape
# Out:
# ((843, 33), (843, 414))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model=Sequential()
model.add(Embedding(total_words, 100, input_length=max_len_input))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)
model.summary()  # Ab params show honge
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0476 - loss: 5.9686
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0626 - loss: 5.5732
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0750 - loss: 5.4366
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0818 - loss: 5.3186
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0702 - loss: 5.4809
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0730 - loss: 5.3403
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0816 - loss: 5.2003
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0652 - loss: 5.1759
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0902 - loss: 4.8875
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0964 - loss: 4.7538
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0970 - loss: 4.6015
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 33, 100)        │        41,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 414)            │        62,514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 763,544 (2.91 MB)
#  Trainable params: 254,514 (994.20 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 509,030 (1.94 MB)

# %%
import numpy as np

def predict_next_word(model, tokenizer, seed_text, max_len_input):
    # Tokenize & pad input
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_len_input, padding='pre')

    # Predict next word
    predicted_probs = model.predict(token_list, verbose=0)
    predicted_index = np.argmax(predicted_probs)

    # Convert index to word
    output_word = tokenizer.index_word.get(predicted_index, '')
    return output_word

# %%
while True:
    seed = input("Enter your text (or 'exit' to quit): ")
    if seed.lower() == 'exit':
        break
    next_word = predict_next_word(model, tokenizer, seed, max_len_input)
    print(f"→ Predicted next word: {next_word}")
